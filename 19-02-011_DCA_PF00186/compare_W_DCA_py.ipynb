# %%
import numpy as np

# %%
wDCA = np.loadtxt('result_W.dat').T

# %%
wDCA.shape
# Out:
# (5, 3871098)

# %%
w = np.loadtxt('ew.dat').T

# %%
w.shape
# Out:
# (5, 3871098)

# %%
w0 = wDCA[4,:]
w1 = w[4,:]
import matplotlib.pyplot as plt

plt.plot([w1.min(),w1.max()],[w1.min(),w1.max()],'r--')
plt.scatter(w0,w1)
plt.savefig('ew_compare.pdf', format='pdf', dpi=100)
plt.show()
