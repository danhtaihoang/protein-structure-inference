# %%
import matplotlib.pyplot as plt
from matplotlib import patches
import numpy as np
import pandas as pd
from scipy.spatial import distance_matrix
import sys, os, Bio.PDB, warnings
pdb_list = Bio.PDB.PDBList()
pdb_parser = Bio.PDB.PDBParser()
data_dir = '../protein_pfam'
sys.path.append(data_dir)
from parse_pfam import parse_pfam
from Bio import BiopythonWarning
warnings.simplefilter('ignore', BiopythonWarning)
# %matplotlib inline

# %%
pfam, pdb_refs = parse_pfam(data_dir)
print 'total MSAs: %i, total PDB refs: %i' % (pfam.shape[0], pdb_refs.shape[0])
# Out:
# total MSAs: 17772, total PDB refs: 249704

# %%
# Cas 9 family accesion code
ac = 'PF00186'
# store the family of interest in the 'fam' variable
fam = pfam.loc[ac]
#print 'size rank: %i of %i' % (pfam['size'].rank(ascending=False)[fam.name].astype(int), pfam.shape[0])

# %%
fam
# Out:
# res          918
# seq         7750
# pdb_refs     382
# Name: PF00186, dtype: int64

# %%
# local directory containing data for this MSA
fam_dir = os.path.join(data_dir, 'Pfam-A.full', fam.name)

# the residue symbols array that is the MSA
msa = np.load(os.path.join(fam_dir, 'msa.npy'))

# %%
msa.shape
# Out:
# (918, 7750)

# %%
pfam[pfam.index == ac]
# Out:
#          res   seq  pdb_refs
# PF00186  918  7750       382

# %% [markdown]
# # find pdb reference:

# %%
refs = pdb_refs[pdb_refs.index.str.contains(fam.name)]
refs.head()
# Out:
#          seq    uniprot_id  uniprot_start  uniprot_end pdb_id chain  \
# PF00186   68  Q5KZ26_GEOKA              1          160   1ZDR     B
# PF00186   68  Q5KZ26_GEOKA              1          160   1ZDR     A
# PF00186   82  Q81R22_BACAN              2          160   3JWK     B
# PF00186   82  Q81R22_BACAN              2          160   3S9U     B
# PF00186   82  Q81R22_BACAN              2          160   3FL9     H
#
#          pdb_start  pdb_end
# PF00186          1      160
# PF00186          1      160
# PF00186          2      160
# PF00186          2      160
# PF00186          2      160

# %%
n_refs = refs.shape[0]
print(n_refs)
# Out:
# 372

# %%
for i in range(n_refs):
    ref = refs.iloc[i]
    #print(ref)

    # pdb sequence
    #seq = msa[:,ref.seq]
    seq = msa[:,ref.seq+1]  # change j-1 --> j
    #print(seq)
    
    gap_pos = seq == '-'
    seq_non_gap = seq[~gap_pos] 

    #print(seq_non_gap.shape)
    #print(seq_non_gap)
    
    pdb_file = pdb_list.retrieve_pdb_file(ref.pdb_id, pdir=fam_dir, file_format='pdb')
    chain = pdb_parser.get_structure(ref.pdb_id, pdb_file)[0][ref.chain]
    coords = np.array([a.get_coord() for a in chain.get_atoms()])
    #print(coords.shape)
    #print(coords)
    coords_cut = coords[ref.pdb_start-1:ref.pdb_end]
    #print(coords_cut.shape)
    
    print(seq_non_gap.shape[0]-coords_cut.shape[0])
# Out:
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1zdr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1zdr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwk.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3s9u.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3s9u.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jw3.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3dat.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3sa1.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3sai.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwc.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jvx.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3sa1.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jw3.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3sai.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwc.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwm.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3e0b.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3sa2.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2qk8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwk.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jw5.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3sa2.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2kgk.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jwm.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jw5.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3jvx.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elg.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3e0b.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ele.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fl8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4elf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1pd8.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2c2s.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1s3w.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3f8z.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1hfq.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nxy.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1ohk.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4qhv.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2c2t.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kbn.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3ntz.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3eig.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1mvs.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4m6k.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ddr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2w3b.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kak.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nxv.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3ghv.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1kms.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2w3m.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1yho.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kfj.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kd7.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kfj.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4g95.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3oaf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4m6l.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1u72.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1hfr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4qjc.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kbn.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nxx.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nxr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hpb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nu0.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dlr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3gi2.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1u71.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nxt.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nzd.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4m6j.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3f91.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nxo.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3fs6.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3n0h.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hve.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3ghc.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1drf.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2w3a.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3ghw.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1boz.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hqz.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1ohj.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hsu.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hvb.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hqy.ent'
# 0
# Downloading PDB structure '3S7A'...
# 0
# Downloading PDB structure '1MVT'...
# 0
# Downloading PDB structure '5HSR'...
# 0
# Downloading PDB structure '3S3V'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2c2s.ent'
# 0
# Downloading PDB structure '1PDB'...
# 0
# Downloading PDB structure '3L3R'...
# 0
# Downloading PDB structure '1KMV'...
# 0
# Downloading PDB structure '5HUI'...
# 0
# Downloading PDB structure '1S3V'...
# 0
# Downloading PDB structure '1S3U'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2w3b.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kd7.ent'
# 0
# Downloading PDB structure '1DLS'...
# 0
# Downloading PDB structure '3F8Y'...
# 0
# Downloading PDB structure '4KEB'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2c2t.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2w3a.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kak.ent'
# 0
# Downloading PDB structure '5HT4'...
# 0
# Downloading PDB structure '1PD9'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2w3m.ent'
# 0
# Downloading PDB structure '3GYF'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4keb.ent'
# 0
# Downloading PDB structure '5HT5'...
# 0
# Downloading PDB structure '1HFP'...
# 0
# Downloading PDB structure '5UIO'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5uio.ent'
# 0
# Downloading PDB structure '1DHI'...
# 0
# Downloading PDB structure '1RF7'...
# 0
# Downloading PDB structure '4X5H'...
# 0
# Downloading PDB structure '4PDJ'...
# 0
# Downloading PDB structure '1RX4'...
# 0
# Downloading PDB structure '1RX1'...
# 0
# Downloading PDB structure '1RE7'...
# 0
# Downloading PDB structure '3DAU'...
# 0
# Downloading PDB structure '1RX3'...
# 0
# Downloading PDB structure '1RB3'...
# 0
# Downloading PDB structure '4EJ1'...
# 0
# Downloading PDB structure '1DDR'...
# 0
# Downloading PDB structure '4X5F'...
# 0
# Downloading PDB structure '5UJX'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dhi.ent'
# 0
# Downloading PDB structure '5UIH'...
# 0
# Downloading PDB structure '1RA8'...
# 0
# Downloading PDB structure '1RA3'...
# 0
# Downloading PDB structure '5EAJ'...
# 0
# Downloading PDB structure '1RB2'...
# 0
# Downloading PDB structure '1DRA'...
# 0
# Downloading PDB structure '4EIZ'...
# 0
# Downloading PDB structure '2INQ'...
# 0
# Downloading PDB structure '3KFY'...
# 0
# Downloading PDB structure '4I1N'...
# 0
# Downloading PDB structure '1TDR'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dra.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5ujx.ent'
# 0
# Downloading PDB structure '1DDS'...
# 0
# Downloading PDB structure '2DRC'...
# 0
# Downloading PDB structure '1RA9'...
# 0
# Downloading PDB structure '7DFR'...
# 0
# Downloading PDB structure '1RA1'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dds.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1ddr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1rb3.ent'
# 0
# Downloading PDB structure '4I13'...
# 0
# Downloading PDB structure '4NX7'...
# 0
# Downloading PDB structure '1DYH'...
# 0
# Downloading PDB structure '1RH3'...
# 0
# Downloading PDB structure '4NX6'...
# 0
# Downloading PDB structure '1DYJ'...
# 0
# Downloading PDB structure '1RD7'...
# 0
# Downloading PDB structure '5CC9'...
# 0
# Downloading PDB structure '4X5G'...
# 0
# Downloading PDB structure '1RA2'...
# 0
# Downloading PDB structure '1DHJ'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2drc.ent'
# 0
# Downloading PDB structure '4DFR'...
# 0
# Downloading PDB structure '1RX2'...
# 0
# Downloading PDB structure '3QL3'...
# 0
# Downloading PDB structure '1RG7'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5uio.ent'
# 0
# Downloading PDB structure '4FHB'...
# 0
# Downloading PDB structure '2ANQ'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dhj.ent'
# 0
# Downloading PDB structure '1RX7'...
# 0
# Downloading PDB structure '5E8Q'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4x5f.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dyh.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5uio.ent'
# 0
# Downloading PDB structure '4X5I'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1re7.ent'
# 0
# Downloading PDB structure '2D0K'...
# 0
# Downloading PDB structure '5DFR'...
# 0
# Downloading PDB structure '4EIG'...
# 0
# Downloading PDB structure '1JOL'...
# 0
# Downloading PDB structure '3QYL'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5uio.ent'
# 0
# Downloading PDB structure '1RX8'...
# 0
# Downloading PDB structure '2ANO'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5e8q.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4dfr.ent'
# 0
# Downloading PDB structure '1DYI'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2inq.ent'
# 0
# Downloading PDB structure '1RC4'...
# 0
# Downloading PDB structure '5W3Q'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4eiz.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1rb2.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4ej1.ent'
# 0
# Downloading PDB structure '3DRC'...
# 0
# Downloading PDB structure '4KJJ'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3drc.ent'
# 0
# Downloading PDB structure '4KJK'...
# 0
# Downloading PDB structure '1RX5'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1tdr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1jol.ent'
# 0
# Downloading PDB structure '1DRB'...
# 0
# Downloading PDB structure '3OCH'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb2d0k.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3och.ent'
# 0
# Downloading PDB structure '3R33'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1rd7.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dyj.ent'
# 0
# Downloading PDB structure '3K74'...
# 0
# Downloading PDB structure '3QYO'...
# 0
# Downloading PDB structure '1RX6'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1drb.ent'
# 0
# Downloading PDB structure '1RX9'...
# 0
# Downloading PDB structure '4X5J'...
# 0
# Downloading PDB structure '5CCC'...
# 0
# Downloading PDB structure '6DFR'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1dyi.ent'
# 0
# Downloading PDB structure '1DRH'...
# 0
# Downloading PDB structure '1JOM'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5eaj.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4x5g.ent'
# 0
# Downloading PDB structure '1DRE'...
# 0
# Downloading PDB structure '3VCO'...
# 0
# Downloading PDB structure '3NRR'...
# 0
# Downloading PDB structure '3I3R'...
# 0
# Downloading PDB structure '3KJR'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3nrr.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3kjr.ent'
# 0
# Downloading PDB structure '3K2H'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3k2h.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3i3r.ent'
# 0
# Downloading PDB structure '2ITH'...
# 0
# Downloading PDB structure '2JYB'...
# 0
# Downloading PDB structure '1VDR'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1vdr.ent'
# 0
# Downloading PDB structure '4H98'...
# 0
# Downloading PDB structure '3QLX'...
# 0
# Downloading PDB structure '3CSE'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3qlx.ent'
# 0
# Downloading PDB structure '3ROA'...
# 0
# Downloading PDB structure '3EEJ'...
# 0
# Downloading PDB structure '3RO9'...
# 0
# Downloading PDB structure '3EEL'...
# 0
# Downloading PDB structure '3EEM'...
# 0
# Downloading PDB structure '3EEK'...
# 0
# Downloading PDB structure '3QLZ'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3qlz.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3eel.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3eek.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3eem.ent'
# 0
# Downloading PDB structure '4HOG'...
# 0
# Downloading PDB structure '3QLY'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4h98.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3eej.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4hog.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3qly.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3roa.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3ro9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb3cse.ent'
# 0
# Downloading PDB structure '1JUV'...
# 0
# Downloading PDB structure '1CZ3'...
# 0
# Downloading PDB structure '1D1G'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1cz3.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb1d1g.ent'
# 0
# Downloading PDB structure '4QI9'...
# 0
# Downloading PDB structure '5FDA'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4qi9.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4qi9.ent'
# 0
# Downloading PDB structure '5HI6'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5hi6.ent'
# 0
# Downloading PDB structure '3Q1H'...
# 0
# Downloading PDB structure '1DR5'...
# 0
# Downloading PDB structure '1DR4'...
# 0
# Downloading PDB structure '8DFR'...
# 0
# Downloading PDB structure '1DR7'...
# 0
# Downloading PDB structure '1DR3'...
# 0
# Downloading PDB structure '1DR6'...
# 0
# Downloading PDB structure '1DR2'...
# 0
# Downloading PDB structure '1DR1'...
# 0
# Downloading PDB structure '1U70'...
# 0
# Downloading PDB structure '3D84'...
# 0
# Downloading PDB structure '3D80'...
# 0
# Downloading PDB structure '2FZJ'...
# 0
# Downloading PDB structure '3K45'...
# 0
# Downloading PDB structure '3K47'...
# 0
# Downloading PDB structure '3TQB'...
# 0
# Downloading PDB structure '3TQ8'...
# 0
# Downloading PDB structure '3TQ9'...
# 0
# Downloading PDB structure '3TQA'...
# 0
# Downloading PDB structure '5T7O'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5t7o.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5t7o.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb5t7o.ent'
# 0
# Downloading PDB structure '4M2X'...
# 0
# Downloading PDB structure '4KNE'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4m2x.ent'
# 0
# Downloading PDB structure '5UJF'...
# 0
# Downloading PDB structure '1DG8'...
# 0
# Downloading PDB structure '4KLX'...
# 0
# Downloading PDB structure '4KM2'...
# 0
# Downloading PDB structure '1DG7'...
# 0
# Downloading PDB structure '5U27'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4kne.ent'
# 0
# Downloading PDB structure '4KL9'...
# 0
# Downloading PDB structure '4KM0'...
# 0
# Downloading PDB structure '1DF7'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4km2.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4m2x.ent'
# 0
# Downloading PDB structure '5U26'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4km0.ent'
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4m2x.ent'
# 0
# Downloading PDB structure '2CIG'...
# 0
# Structure exists: '../protein_pfam/Pfam-A.full/PF00186/pdb4klx.ent'
# 0
# Downloading PDB structure '1DG5'...
# 0
# Downloading PDB structure '4M7U'...
# 0
# Downloading PDB structure '4M7V'...
# 0
